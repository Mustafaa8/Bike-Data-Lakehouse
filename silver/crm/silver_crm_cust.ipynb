# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
customers = spark.read.table("db_ws.bronze.crm_cust")
customers.display()

# %%
customers = customers.withColumnsRenamed({"ID":"id","CAT":"category","SUBCAT":"subcategory","MAINTENANCE":"maintenance"})
customers.display()
