# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
px = spark.read.table("db_ws.bronze.erp_px")
display(px)

# %%
px = px.withColumnsRenamed({"id":"id","CAT":"category","SUBCAT":"subcategory","MAINTENANCE":"maintenance"})
display(px)

# %%
px.write.format("delta").mode("overwrite").saveAsTable("db_ws.silver.erp_px")
